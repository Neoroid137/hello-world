# %%
2+3
# Out:
# 5

# %%
import numpy as np

# %%
a=np.matrix('1,2,3;4,5,6;7,8,9')

# %%
print a
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
b=np.matrix('1,0,0;0,1,0;0,0,1')
print b
# Out:
# [[1 0 0]
#  [0 1 0]
#  [0 0 1]]

# %%
a*b
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 9]])

# %%
c=np.matrix('1,2,0;3,0,-1;0,-4,1')
print c
# Out:
# [[ 1  2  0]
#  [ 3  0 -1]
#  [ 0 -4  1]]

# %%
a*c
# Out:
# matrix([[  7, -10,   1],
#         [ 19, -16,   1],
#         [ 31, -22,   1]])

# %%
from numpy.linalg import inv,eig

# %%
inv(a)
# Out:
# matrix([[ -4.50359963e+15,   9.00719925e+15,  -4.50359963e+15],
#         [  9.00719925e+15,  -1.80143985e+16,   9.00719925e+15],
#         [ -4.50359963e+15,   9.00719925e+15,  -4.50359963e+15]])

# %%
inv(b)
# Out:
# matrix([[ 1.,  0.,  0.],
#         [ 0.,  1.,  0.],
#         [ 0.,  0.,  1.]])

# %%
inv (c)
# Out:
# matrix([[ 0.4,  0.2,  0.2],
#         [ 0.3, -0.1, -0.1],
#         [ 1.2, -0.4,  0.6]])

# %%
p,q=eig(c)

# %%
print p
# Out:
# [-2.70156212  1.          3.70156212]

# %%
print q
# Out:
# [[  3.44512497e-01   3.16227766e-01  -3.82790453e-01]
#  [ -6.37617204e-01  -6.28421574e-17  -5.17066094e-01]
#  [ -6.89024993e-01   9.48683298e-01   7.65580906e-01]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(p)
plt.show()

# %%
import matplotlib.image as kimg

# %%
img=kimg.imread('/home/kartik/Downloads/taj_mahal.png')

# %%
imgplot=plt.imshow(img)

# %%
lum_img=img[:, :,0]
plt.imshow(lum_img)

# %%
plt.imshow(lum_img, cmap="hot")

# %%
plt.hist(lum_img.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k')
# Out:
# (array([   700.,    557.,    953.,   1315.,   2034.,   2815.,   3501.,
#           3778.,   3956.,   3703.,   3465.,   3151.,   2688.,   2443.,
#           2014.,   1827.,   1622.,   1426.,   1302.,   1169.,   1071.,
#            956.,    917.,    882.,    880.,    817.,    748.,    722.,
#            644.,    596.,    539.,    510.,    490.,    494.,    500.,
#            488.,    472.,    466.,    516.,    456.,    474.,    424.,
#            422.,    443.,    411.,    385.,    424.,    381.,    374.,
#            375.,    388.,    362.,    398.,    367.,    362.,    338.,
#            381.,    405.,    369.,    360.,    375.,    369.,    338.,
#            357.,    418.,    376.,    361.,    368.,    409.,    388.,
#            412.,    412.,    392.,    424.,    462.,    477.,    491.,
#            481.,    538.,    510.,    546.,    582.,    584.,    578.,
#            609.,    691.,    653.,    707.,    686.,    745.,    763.,
# ...

# %%
imgplot = plt.imshow(lum_img, clim=(0.0, 0.9))

# %%
from PIL import Image
img=Image.open('/home/kartik/Downloads/taj_mahal.png')
img.thumbnail((100,34),Image.ANTIALIAS)
imgplot=plt.imshow(img)

# %%
imgplot=plt.imshow(img,interpolation="nearest")

# %%
imgplot = plt.imshow(img, interpolation="bicubic")

# %%
plt.rcParams['image.cmap']='gray'
plt.rcParams['image.interpolation']='none'

# %%
implot=plt.imshow(img)

# %%
horizontal_edge_kernel = np.array([[ 1,  2,  1],
                                   [ 0,  0,  0],
                                   [-1, -2, -1]])

# %%
plt.imshow(horizontal_edge_kernel, cmap=plt.cm.RdBu);
